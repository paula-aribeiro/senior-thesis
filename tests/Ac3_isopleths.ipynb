# %%
# %matplotlib inline
# %run multidim_database.py -f mn
# %run multidim_database.py -f si
# %run multidim_database.py -f cr
# %run multidim_database.py -f ni
# Out:
# [11, 5, 5, 5, 5]
# [11, 5, 5, 5, 5]
# [11, 5, 5, 5, 5]
# [11, 5, 5, 5, 5]
